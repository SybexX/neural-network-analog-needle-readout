# %% [markdown]
# # CNN Training
#
# Target of this code is to train a CNN network to extract the needle position of an analog needle device.
#
# ### Preparing the training
# * First all libraries are loaded
#     * It is assumed, that they are installed during the Python setup
# * matplotlib is set to print the output inline in the jupyter notebook

# %%
########### Basic Parameters for Running: ################################
    
TFlite_Version  = "1505"   
TFlite_MainType = "ana-cont"
TFlite_Size     = "s2"
Training_Percentage = 0.15              # 0.0 = Use all Images for Training

##########################################################################

## 2024-03-30: Code adapted to TF 2.16####################################



import os
import tensorflow as tf
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.utils import shuffle
from tensorflow.python import keras
from tensorflow.python.keras import Sequential
from tensorflow.keras.layers import Dense, InputLayer, Conv2D, MaxPool2D, Flatten, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import History 
import math
from PIL import Image 

loss_ges = np.array([])
val_loss_ges = np.array([])

# %matplotlib inline
np.set_printoptions(precision=4)
np.set_printoptions(suppress=True)

# %% [markdown]
# ### Load training data
# * The data is expected in the "Input_dir"
# * Picture size must be 32x32 with 3 color channels (RGB)
# * The filename contains the informations needed for training in the first 3 digits::
# * Typical filename:
#     * x.y-zzzz.jpg
#     * e.g. "4.6_Lfd-1406_zeiger3_2019-06-02T050011"
#
# |Place holder | Meaning                     | Usage        |
# |------------- |-----------------------------|--------------|
# | **x.y**          | readout value               | **to be learned** |
# | zzzz        | additional information              | not needed   |
#
# * The images are stored in the x_data[]
# * The expected output for each image in the corresponding y_data[]
#     * The periodic nature is reflected in a **sin/cos coding**, which allows to restore the angle/counter value with an arctan later on.
#
# * The last step is a shuffle (from sklearn.utils) as the filenames are on order due to the encoding of the expected analog readout in the filename

# %%
Input_dir='data_resize_all'

files = glob.glob(Input_dir + '/*.*')
x_data = []
y_data = []

for aktfile in files:
    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    test_image = np.reshape(test_image, (32,32,3))
    base = os.path.basename(aktfile)
    target_number = (float(base[0:3])) / 10
    target_sin = math.sin(target_number * math.pi * 2)
    target_cos = math.cos(target_number * math.pi * 2)

    x_data.append(test_image)
    zw = np.array([target_sin, target_cos])
    y_data.append(zw)

x_data = np.array(x_data)
y_data = np.array(y_data)
print(x_data.shape)
print(y_data.shape)

x_data, y_data = shuffle(x_data, y_data)

if (Training_Percentage > 0):
    X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size=Training_Percentage)
else:
    X_train = x_data
    y_train = y_data
# Out:
# (3478, 32, 32, 3)
# (3478, 2)

# %% [markdown]
# ### Define the model
#
# The layout of the network ist a typcial CNN network with alternating **Conv2D** and **MaxPool2D** layers. Finished after **flattening** with additional **Dense** layer.
#
# #### Important
# * Shape of the input layer: (32, 32, 3)
# * Shape of the output layer: (2) - sin and cos

# %%
inputs = tf.keras.Input(shape=(32, 32, 3))
inputs2 = tf.keras.layers.BatchNormalization()(inputs)
inputs3 = tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation="relu")(inputs2)
inputs4 = tf.keras.layers.MaxPool2D(pool_size=(4,4))(inputs3)
x = tf.keras.layers.BatchNormalization()(inputs4)
inputs5 = tf.keras.layers.Conv2D(16, (5, 5), padding='same', activation="relu")(x)
inputs6 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(inputs5)
x = tf.keras.layers.BatchNormalization()(inputs6)
inputs7 = tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation="relu")(x)
inputs8 = tf.keras.layers.MaxPool2D(pool_size=(2,2))(inputs7)
inputs9 = tf.keras.layers.Flatten()(inputs8)
x = tf.keras.layers.BatchNormalization()(inputs9)
x = tf.keras.layers.Dropout(0.2)(x)
inputs10 = tf.keras.layers.Dense(128,activation="relu")(x)
x = tf.keras.layers.BatchNormalization()(inputs9)
x = tf.keras.layers.Dropout(0.2)(x)
inputs11 = tf.keras.layers.Dense(64,activation="relu")(inputs10)
output = tf.keras.layers.Dense(2)(inputs11)

model = tf.keras.Model(inputs=inputs, outputs=output)

model.compile(loss=keras.losses.mean_squared_error, optimizer=tf.keras.optimizers.Adadelta(learning_rate=1.0, rho=0.95), metrics = ["accuracy"])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  batch_normalization (BatchN  (None, 32, 32, 3)        12
#  ormalization)
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        2432
#
#  max_pooling2d (MaxPooling2D  (None, 8, 8, 32)         0
#  )
#
#  batch_normalization_1 (Batc  (None, 8, 8, 32)         128
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 16)          12816
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 16)         0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 4, 4, 16)         64
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 32)          4640
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 32)         0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 45,502
# Trainable params: 45,144
# Non-trainable params: 358
# _________________________________________________________________

# %% [markdown]
# # Training
# The input pictures are randomly scattered for brightness and pixel shift variations. These is implemented with a ImageDataGenerator.
#
#
# The training is splitted into two steps:
# 1. Variation of the brightness only
# 2. Variation of brightness and Pixel Shift

# %% [markdown]
# ### Step 1: Brigthness scattering only

# %%
from keras.callbacks import EarlyStopping, LearningRateScheduler, ModelCheckpoint, ReduceLROnPlateau

TFliteNamingAndVersion = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size
earlystop = EarlyStopping(monitor='val_loss', mode='min' , patience=15, verbose=1,  restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.9, patience=5, min_lr=1e-5, verbose=1)


Batch_Size = 8
Epoch_Anz = 250
Shift_Range = 0
Brightness_Range = 0.3

datagen = ImageDataGenerator(width_shift_range=[-Shift_Range,Shift_Range], height_shift_range=[-Shift_Range,Shift_Range],brightness_range=[1-Brightness_Range,1+Brightness_Range])

if (Training_Percentage > 0):
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    validation_iterator = datagen.flow(X_test, y_test, batch_size=Batch_Size)
    history = model.fit(train_iterator, 
            validation_data=validation_iterator, 
            batch_size=Batch_Size, 
            epochs = Epoch_Anz,
            callbacks=[earlystop, reduce_lr],
            verbose=1)
else:
    train_iterator = datagen.flow(x_data, y_data, batch_size=Batch_Size)
    history = model.fit(train_iterator, epochs = Epoch_Anz)
# Out:
# Epoch 1/250
# 435/435 [==============================] - 5s 9ms/step - loss: 0.5378 - accuracy: 0.5779 - val_loss: 0.3520 - val_accuracy: 0.7280 - lr: 1.0000
# Epoch 2/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.3256 - accuracy: 0.7608 - val_loss: 0.1686 - val_accuracy: 0.8525 - lr: 1.0000
# Epoch 3/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.2057 - accuracy: 0.8396 - val_loss: 0.0954 - val_accuracy: 0.9291 - lr: 1.0000
# Epoch 4/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.1486 - accuracy: 0.8784 - val_loss: 0.0741 - val_accuracy: 0.9444 - lr: 1.0000
# Epoch 5/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.1178 - accuracy: 0.9031 - val_loss: 0.0485 - val_accuracy: 0.9598 - lr: 1.0000
# Epoch 6/250
# 435/435 [==============================] - 3s 8ms/step - loss: 0.1012 - accuracy: 0.9186 - val_loss: 0.0492 - val_accuracy: 0.9502 - lr: 1.0000
# Epoch 7/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0820 - accuracy: 0.9247 - val_loss: 0.0459 - val_accuracy: 0.9693 - lr: 1.0000
# Epoch 8/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0718 - accuracy: 0.9290 - val_loss: 0.0299 - val_accuracy: 0.9559 - lr: 1.0000
# Epoch 9/250
# 435/435 [==============================] - 3s 8ms/step - loss: 0.0620 - accuracy: 0.9439 - val_loss: 0.0356 - val_accuracy: 0.9598 - lr: 1.0000
# Epoch 10/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0538 - accuracy: 0.9390 - val_loss: 0.0234 - val_accuracy: 0.9636 - lr: 1.0000
# Epoch 11/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0494 - accuracy: 0.9485 - val_loss: 0.0230 - val_accuracy: 0.9655 - lr: 1.0000
# Epoch 12/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0474 - accuracy: 0.9462 - val_loss: 0.0193 - val_accuracy: 0.9732 - lr: 1.0000
# Epoch 13/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0425 - accuracy: 0.9497 - val_loss: 0.0221 - val_accuracy: 0.9617 - lr: 1.0000
# Epoch 14/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0397 - accuracy: 0.9477 - val_loss: 0.0186 - val_accuracy: 0.9693 - lr: 1.0000
# Epoch 15/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0369 - accuracy: 0.9534 - val_loss: 0.0161 - val_accuracy: 0.9828 - lr: 1.0000
# Epoch 16/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0371 - accuracy: 0.9557 - val_loss: 0.0181 - val_accuracy: 0.9847 - lr: 1.0000
# Epoch 17/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0338 - accuracy: 0.9554 - val_loss: 0.0176 - val_accuracy: 0.9770 - lr: 1.0000
# Epoch 18/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0323 - accuracy: 0.9557 - val_loss: 0.0153 - val_accuracy: 0.9808 - lr: 1.0000
# Epoch 19/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0330 - accuracy: 0.9531 - val_loss: 0.0175 - val_accuracy: 0.9828 - lr: 1.0000
# Epoch 20/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0303 - accuracy: 0.9620 - val_loss: 0.0122 - val_accuracy: 0.9770 - lr: 1.0000
# Epoch 21/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0281 - accuracy: 0.9615 - val_loss: 0.0141 - val_accuracy: 0.9789 - lr: 1.0000
# Epoch 22/250
# 435/435 [==============================] - 3s 8ms/step - loss: 0.0279 - accuracy: 0.9566 - val_loss: 0.0141 - val_accuracy: 0.9808 - lr: 1.0000
# Epoch 23/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0269 - accuracy: 0.9546 - val_loss: 0.0119 - val_accuracy: 0.9693 - lr: 1.0000
# Epoch 24/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0264 - accuracy: 0.9629 - val_loss: 0.0114 - val_accuracy: 0.9808 - lr: 1.0000
# Epoch 25/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0251 - accuracy: 0.9569 - val_loss: 0.0107 - val_accuracy: 0.9713 - lr: 1.0000
# Epoch 26/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0243 - accuracy: 0.9574 - val_loss: 0.0118 - val_accuracy: 0.9866 - lr: 1.0000
# Epoch 27/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0229 - accuracy: 0.9658 - val_loss: 0.0082 - val_accuracy: 0.9923 - lr: 1.0000
# Epoch 28/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0233 - accuracy: 0.9606 - val_loss: 0.0114 - val_accuracy: 0.9866 - lr: 1.0000
# Epoch 29/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0227 - accuracy: 0.9620 - val_loss: 0.0101 - val_accuracy: 0.9770 - lr: 1.0000
# Epoch 30/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0224 - accuracy: 0.9661 - val_loss: 0.0074 - val_accuracy: 0.9808 - lr: 1.0000
# Epoch 31/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0206 - accuracy: 0.9672 - val_loss: 0.0094 - val_accuracy: 0.9808 - lr: 1.0000
# Epoch 32/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0197 - accuracy: 0.9635 - val_loss: 0.0090 - val_accuracy: 0.9866 - lr: 1.0000
# Epoch 33/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0207 - accuracy: 0.9664 - val_loss: 0.0071 - val_accuracy: 0.9847 - lr: 1.0000
# Epoch 34/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0191 - accuracy: 0.9638 - val_loss: 0.0073 - val_accuracy: 0.9904 - lr: 1.0000
# Epoch 35/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0191 - accuracy: 0.9669 - val_loss: 0.0106 - val_accuracy: 0.9904 - lr: 1.0000
# Epoch 36/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0191 - accuracy: 0.9606 - val_loss: 0.0085 - val_accuracy: 0.9866 - lr: 1.0000
# Epoch 37/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0172 - accuracy: 0.9649 - val_loss: 0.0083 - val_accuracy: 0.9847 - lr: 1.0000
# Epoch 38/250
# 434/435 [============================>.] - ETA: 0s - loss: 0.0178 - accuracy: 0.9648
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.9.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0178 - accuracy: 0.9649 - val_loss: 0.0083 - val_accuracy: 0.9866 - lr: 1.0000
# Epoch 39/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0159 - accuracy: 0.9664 - val_loss: 0.0070 - val_accuracy: 0.9808 - lr: 0.9000
# Epoch 40/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0167 - accuracy: 0.9675 - val_loss: 0.0083 - val_accuracy: 0.9866 - lr: 0.9000
# Epoch 41/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0160 - accuracy: 0.9684 - val_loss: 0.0063 - val_accuracy: 0.9828 - lr: 0.9000
# Epoch 42/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0151 - accuracy: 0.9669 - val_loss: 0.0064 - val_accuracy: 0.9789 - lr: 0.9000
# Epoch 43/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0148 - accuracy: 0.9666 - val_loss: 0.0082 - val_accuracy: 0.9866 - lr: 0.9000
# Epoch 44/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0155 - accuracy: 0.9658 - val_loss: 0.0069 - val_accuracy: 0.9885 - lr: 0.9000
# Epoch 45/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0151 - accuracy: 0.9658 - val_loss: 0.0068 - val_accuracy: 0.9885 - lr: 0.9000
# Epoch 46/250
# 433/435 [============================>.] - ETA: 0s - loss: 0.0137 - accuracy: 0.9674
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.8099999785423279.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0137 - accuracy: 0.9669 - val_loss: 0.0066 - val_accuracy: 0.9847 - lr: 0.9000
# Epoch 47/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0118 - accuracy: 0.9738 - val_loss: 0.0054 - val_accuracy: 0.9866 - lr: 0.8100
# Epoch 48/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0134 - accuracy: 0.9735 - val_loss: 0.0060 - val_accuracy: 0.9847 - lr: 0.8100
# Epoch 49/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0134 - accuracy: 0.9658 - val_loss: 0.0056 - val_accuracy: 0.9904 - lr: 0.8100
# Epoch 50/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0134 - accuracy: 0.9687 - val_loss: 0.0055 - val_accuracy: 0.9828 - lr: 0.8100
# Epoch 51/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0132 - accuracy: 0.9655 - val_loss: 0.0051 - val_accuracy: 0.9885 - lr: 0.8100
# Epoch 52/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0125 - accuracy: 0.9712 - val_loss: 0.0073 - val_accuracy: 0.9847 - lr: 0.8100
# Epoch 53/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0132 - accuracy: 0.9698 - val_loss: 0.0044 - val_accuracy: 0.9904 - lr: 0.8100
# Epoch 54/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0121 - accuracy: 0.9704 - val_loss: 0.0042 - val_accuracy: 0.9923 - lr: 0.8100
# Epoch 55/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0115 - accuracy: 0.9727 - val_loss: 0.0053 - val_accuracy: 0.9885 - lr: 0.8100
# Epoch 56/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0120 - accuracy: 0.9695 - val_loss: 0.0041 - val_accuracy: 0.9847 - lr: 0.8100
# Epoch 57/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0125 - accuracy: 0.9701 - val_loss: 0.0067 - val_accuracy: 0.9847 - lr: 0.8100
# Epoch 58/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0114 - accuracy: 0.9704 - val_loss: 0.0042 - val_accuracy: 0.9808 - lr: 0.8100
# Epoch 59/250
# 430/435 [============================>.] - ETA: 0s - loss: 0.0114 - accuracy: 0.9695
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.7290000021457672.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0114 - accuracy: 0.9695 - val_loss: 0.0064 - val_accuracy: 0.9828 - lr: 0.8100
# Epoch 60/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0112 - accuracy: 0.9675 - val_loss: 0.0054 - val_accuracy: 0.9847 - lr: 0.7290
# Epoch 61/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0106 - accuracy: 0.9712 - val_loss: 0.0054 - val_accuracy: 0.9885 - lr: 0.7290
# Epoch 62/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0116 - accuracy: 0.9684 - val_loss: 0.0040 - val_accuracy: 0.9923 - lr: 0.7290
# Epoch 63/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0105 - accuracy: 0.9698 - val_loss: 0.0040 - val_accuracy: 0.9828 - lr: 0.7290
# Epoch 64/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0100 - accuracy: 0.9733 - val_loss: 0.0051 - val_accuracy: 0.9847 - lr: 0.7290
# Epoch 65/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0098 - accuracy: 0.9712 - val_loss: 0.0034 - val_accuracy: 0.9904 - lr: 0.7290
# Epoch 66/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0102 - accuracy: 0.9753 - val_loss: 0.0041 - val_accuracy: 0.9923 - lr: 0.7290
# Epoch 67/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0098 - accuracy: 0.9715 - val_loss: 0.0039 - val_accuracy: 0.9866 - lr: 0.7290
# Epoch 68/250
# 435/435 [==============================] - 3s 8ms/step - loss: 0.0100 - accuracy: 0.9764 - val_loss: 0.0034 - val_accuracy: 0.9923 - lr: 0.7290
# Epoch 69/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0098 - accuracy: 0.9715 - val_loss: 0.0036 - val_accuracy: 0.9904 - lr: 0.7290
# Epoch 70/250
# 434/435 [============================>.] - ETA: 0s - loss: 0.0100 - accuracy: 0.9700
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.6560999751091003.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0100 - accuracy: 0.9701 - val_loss: 0.0035 - val_accuracy: 0.9885 - lr: 0.7290
# Epoch 71/250
# 435/435 [==============================] - 4s 10ms/step - loss: 0.0090 - accuracy: 0.9707 - val_loss: 0.0046 - val_accuracy: 0.9866 - lr: 0.6561
# Epoch 72/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0090 - accuracy: 0.9750 - val_loss: 0.0041 - val_accuracy: 0.9885 - lr: 0.6561
# Epoch 73/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0086 - accuracy: 0.9730 - val_loss: 0.0037 - val_accuracy: 0.9904 - lr: 0.6561
# Epoch 74/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0087 - accuracy: 0.9744 - val_loss: 0.0037 - val_accuracy: 0.9943 - lr: 0.6561
# Epoch 75/250
# 431/435 [============================>.] - ETA: 0s - loss: 0.0084 - accuracy: 0.9716
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.5904899775981903.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0084 - accuracy: 0.9718 - val_loss: 0.0036 - val_accuracy: 0.9866 - lr: 0.6561
# Epoch 76/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0084 - accuracy: 0.9741 - val_loss: 0.0035 - val_accuracy: 0.9962 - lr: 0.5905
# Epoch 77/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0085 - accuracy: 0.9727 - val_loss: 0.0025 - val_accuracy: 0.9943 - lr: 0.5905
# Epoch 78/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0080 - accuracy: 0.9773 - val_loss: 0.0026 - val_accuracy: 0.9923 - lr: 0.5905
# Epoch 79/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0087 - accuracy: 0.9721 - val_loss: 0.0040 - val_accuracy: 0.9923 - lr: 0.5905
# Epoch 80/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0084 - accuracy: 0.9735 - val_loss: 0.0029 - val_accuracy: 0.9885 - lr: 0.5905
# Epoch 81/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0086 - accuracy: 0.9758 - val_loss: 0.0032 - val_accuracy: 0.9847 - lr: 0.5905
# Epoch 82/250
# 430/435 [============================>.] - ETA: 0s - loss: 0.0078 - accuracy: 0.9770
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.5314409852027894.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0079 - accuracy: 0.9770 - val_loss: 0.0034 - val_accuracy: 0.9904 - lr: 0.5905
# Epoch 83/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0083 - accuracy: 0.9756 - val_loss: 0.0028 - val_accuracy: 0.9885 - lr: 0.5314
# Epoch 84/250
# 435/435 [==============================] - 4s 10ms/step - loss: 0.0078 - accuracy: 0.9764 - val_loss: 0.0029 - val_accuracy: 0.9885 - lr: 0.5314
# Epoch 85/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0080 - accuracy: 0.9750 - val_loss: 0.0030 - val_accuracy: 0.9904 - lr: 0.5314
# Epoch 86/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0081 - accuracy: 0.9770 - val_loss: 0.0032 - val_accuracy: 0.9904 - lr: 0.5314
# Epoch 87/250
# 431/435 [============================>.] - ETA: 0s - loss: 0.0080 - accuracy: 0.9748
# Epoch 87: ReduceLROnPlateau reducing learning rate to 0.4782968759536743.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0080 - accuracy: 0.9747 - val_loss: 0.0034 - val_accuracy: 0.9904 - lr: 0.5314
# Epoch 88/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0072 - accuracy: 0.9718 - val_loss: 0.0027 - val_accuracy: 0.9943 - lr: 0.4783
# Epoch 89/250
# 435/435 [==============================] - 3s 8ms/step - loss: 0.0070 - accuracy: 0.9804 - val_loss: 0.0028 - val_accuracy: 0.9943 - lr: 0.4783
# Epoch 90/250
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0076 - accuracy: 0.9727 - val_loss: 0.0027 - val_accuracy: 0.9904 - lr: 0.4783
# Epoch 91/250
# 435/435 [==============================] - 4s 8ms/step - loss: 0.0072 - accuracy: 0.9779 - val_loss: 0.0028 - val_accuracy: 0.9847 - lr: 0.4783
# Epoch 92/250
# 432/435 [============================>.] - ETA: 0s - loss: 0.0075 - accuracy: 0.9760Restoring model weights from the end of the best epoch: 77.
#
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.4304671883583069.
# 435/435 [==============================] - 4s 9ms/step - loss: 0.0075 - accuracy: 0.9761 - val_loss: 0.0027 - val_accuracy: 0.9923 - lr: 0.4783
# Epoch 92: early stopping

# %% [raw]
# ### Step 1: Learing result
#
# * Visualization of the training and validation results

# %%
loss_ges = np.append(loss_ges, history.history['loss'])

if (Training_Percentage > 0):
    val_loss_ges = np.append(val_loss_ges, history.history['val_loss'])
    plt.semilogy(val_loss_ges)

plt.semilogy(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','eval'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the model by hand
#
# * The following code uses the trained model to check the deviation for each picture.
# * The evaluation takes the periodic character of the results into account (dev1 ... dev2).
# * Images, that have a bigger deviation as the parameter "deviation_max_list" are printed in a list to check the picture and labeling itself

# %%
Input_dir='data_resize_all'
#Input_dir='test_result'
files = glob.glob(Input_dir + '/*.*')
res = []
stat_Anz = []
stat_Abweichung = []
i = 0
deviation_max_list = 0.15

for i in range(100):
    stat_Anz.append(0)
    stat_Abweichung.append(0)

for aktfile in sorted(files):
    base = os.path.basename(aktfile)
    target = (float(base[0:3])) / 10
    
    target_sin = math.sin(target * math.pi * 2)
    target_cos = math.cos(target * math.pi * 2)

    test_image = Image.open(aktfile)
    test_image = np.array(test_image, dtype="float32")
    img = np.reshape(test_image,[1,32,32,3])
    classes = model.predict(img, verbose=0)
    
    out_sin = classes[0][0]  
    out_cos = classes[0][1]
    out_target = (np.arctan2(out_sin, out_cos)/(2*math.pi)) % 1

    dev_sin = target_sin - out_sin
    dev_cos = target_cos - out_cos
    dev_target = target - out_target
    
    if abs(dev_target + 1) < abs(dev_target):
        out_target = out_target - 1
        dev_target = target - out_target
    else:
        if abs(dev_target - 1) < abs(dev_target):
            out_target = out_target + 1
            dev_target = target - out_target
            
    target_int = int ((float(base[0:3])) * 10)
    stat_Abweichung[target_int] = stat_Abweichung[target_int] + dev_target  
    stat_Anz[target_int] = stat_Anz[target_int] + 1
               
    res.append(np.array([target, out_target, dev_target, out_sin, out_cos, i]))
    if abs(dev_target) > deviation_max_list:
        print(aktfile + " " + str(target) + " " + str(out_target) +  " " + str(dev_target))

    
for i in range(100):
    stat_Abweichung[i] = stat_Abweichung[i] / stat_Anz[i]

res = np.asarray(res)
res_step_1 = res

# %% [markdown]
# ## Results

# %%
plt.plot(res[:,3])
plt.plot(res[:,4])
plt.title('Result')
plt.ylabel('value')
plt.xlabel('#Picture')
plt.legend(['sin', 'cos'], loc='lower left')
plt.show()

# %%
plt.plot(res[:,0])
plt.plot(res[:,1])
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %%
plt.plot(stat_Abweichung)
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %%
plt.plot(stat_Anz)
plt.title('Result')
plt.ylabel('Counter Value')
plt.xlabel('#Picture')
plt.legend(['Orginal', 'Prediction'], loc='upper left')
plt.show()

# %% [markdown]
# ### Deviation from Expected Value

# %%
plt.plot(res[:,2])
plt.title('Deviation')
plt.ylabel('Deviation from expected value')
plt.xlabel('#Picture')
plt.legend(['Deviation'], loc='upper left')
#plt.ylim(-0.3, 0.3)
plt.show()

statistic = np.array([np.mean(res[:,2]), np.std(res[:,2]), np.min(res[:,2]), np.max(res[:,2])])
print(statistic)
# Out:
# [ 0.0006  0.0086 -0.0339  0.0365]

# %% [markdown]
# ### Save the model
#
# * Save the model to the file with the "h5" file format

# %%
FileName = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
open(FileName + ".tflite", "wb").write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Michael\AppData\Local\Temp\tmpl7ykxydj\assets
# INFO:tensorflow:Assets written to: C:\Users\Michael\AppData\Local\Temp\tmpl7ykxydj\assets
# 185684

# %%
from pathlib import Path
import tensorflow as tf

FileName = TFlite_MainType + "_" + TFlite_Version + "_" + TFlite_Size + "_q.tflite"

def representative_dataset():
    for n in range(x_data[0].size):
      data = np.expand_dims(x_data[n], axis=0)
      yield [data.astype(np.float32)]

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.representative_dataset = representative_dataset
converter._experimental_disable_per_channel_quantization_for_dense_layers = True
tflite_quant_model = converter.convert()

open(FileName, "wb").write(tflite_quant_model)
print(FileName)
Path(FileName).stat().st_size
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\Michael\AppData\Local\Temp\tmpncr6_gl9\assets
# INFO:tensorflow:Assets written to: C:\Users\Michael\AppData\Local\Temp\tmpncr6_gl9\assets
# C:\Users\Michael\AppData\Roaming\Python\Python310\site-packages\tensorflow\lite\python\convert.py:766: UserWarning: Statistics for quantized inputs were expected, but not specified; continuing anyway.
#   warnings.warn("Statistics for quantized inputs were expected, but not "
# ana-cont_1505_s2_q.tflite
# 55272
